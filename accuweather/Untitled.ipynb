# %% [markdown]
# # Use Python urllib Open AccuWeather API

# %%
import urllib.request, json

# %%
url = 'http://api.accuweather.com/currentconditions/v1/3-315078_1_AL.json?apikey=ff1b463d98fb47af848ea2843ec5c925&language=zh-tw&details=true'

# %%
with urllib.request.urlopen(url) as reader:
    curr_weather = json.loads(reader.read().decode('utf-8'))
    print(curr_weather)
# Out:
# [{'RelativeHumidity': 77, 'ApparentTemperature': {'Imperial': {'Value': 65.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 18.3, 'UnitType': 17, 'Unit': 'C'}}, 'WeatherIcon': 7, 'UVIndex': 0, 'Pressure': {'Imperial': {'Value': 30.12, 'UnitType': 12, 'Unit': 'inHg'}, 'Metric': {'Value': 1020.0, 'UnitType': 14, 'Unit': 'mb'}}, 'UVIndexText': '低', 'WetBulbTemperature': {'Imperial': {'Value': 58.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 14.7, 'UnitType': 17, 'Unit': 'C'}}, 'Ceiling': {'Imperial': {'Value': 2900.0, 'UnitType': 0, 'Unit': 'ft'}, 'Metric': {'Value': 884.0, 'UnitType': 5, 'Unit': 'm'}}, 'EpochTime': 1452244800, 'RealFeelTemperatureShade': {'Imperial': {'Value': 57.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 13.7, 'UnitType': 17, 'Unit': 'C'}}, 'WeatherText': '多雲', 'WindChillTemperature': {'Imperial': {'Value': 63.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 17.2, 'UnitType': 17, 'Unit': 'C'}}, 'PressureTendency': {'Code': 'S', 'LocalizedText': '穩定'}, 'DewPoint': {'Imperial': {'Value': 55.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 12.8, 'UnitType': 17, 'Unit': 'C'}}, 'CloudCover': 95, 'Temperature': {'Imperial': {'Value': 63.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 17.2, 'UnitType': 17, 'Unit': 'C'}}, 'MobileLink': 'http://m.accuweather.com/zh/tw/taipei-city/315078/current-weather/315078?lang=zh-tw', 'TemperatureSummary': {'Past24HourRange': {'Minimum': {'Imperial': {'Value': 61.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 16.1, 'UnitType': 17, 'Unit': 'C'}}, 'Maximum': {'Imperial': {'Value': 64.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 18.0, 'UnitType': 17, 'Unit': 'C'}}}, 'Past6HourRange': {'Minimum': {'Imperial': {'Value': 63.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 17.2, 'UnitType': 17, 'Unit': 'C'}}, 'Maximum': {'Imperial': {'Value': 64.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 18.0, 'UnitType': 17, 'Unit': 'C'}}}, 'Past12HourRange': {'Minimum': {'Imperial': {'Value': 62.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 16.8, 'UnitType': 17, 'Unit': 'C'}}, 'Maximum': {'Imperial': {'Value': 64.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 18.0, 'UnitType': 17, 'Unit': 'C'}}}}, 'Visibility': {'Imperial': {'Value': 6.0, 'UnitType': 2, 'Unit': 'mi'}, 'Metric': {'Value': 9.7, 'UnitType': 6, 'Unit': 'km'}}, 'WindGust': {'Speed': {'Imperial': {'Value': 21.9, 'UnitType': 9, 'Unit': 'mi/h'}, 'Metric': {'Value': 35.2, 'UnitType': 7, 'Unit': 'km/h'}}}, 'IsDayTime': False, 'LocalObservationDateTime': '2016-01-08T17:20:00+08:00', 'ObstructionsToVisibility': '', 'PrecipitationSummary': {'Past9Hours': {'Imperial': {'Value': 0.0, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 0.0, 'UnitType': 3, 'Unit': 'mm'}}, 'Past12Hours': {'Imperial': {'Value': 0.03, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 1.0, 'UnitType': 3, 'Unit': 'mm'}}, 'Precipitation': {'Imperial': {'Value': 0.0, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 0.0, 'UnitType': 3, 'Unit': 'mm'}}, 'Past3Hours': {'Imperial': {'Value': 0.0, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 0.0, 'UnitType': 3, 'Unit': 'mm'}}, 'Past18Hours': {'Imperial': {'Value': 0.11, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 3.0, 'UnitType': 3, 'Unit': 'mm'}}, 'PastHour': {'Imperial': {'Value': 0.0, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 0.0, 'UnitType': 3, 'Unit': 'mm'}}, 'Past24Hours': {'Imperial': {'Value': 0.11, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 3.0, 'UnitType': 3, 'Unit': 'mm'}}, 'Past6Hours': {'Imperial': {'Value': 0.0, 'UnitType': 1, 'Unit': 'in'}, 'Metric': {'Value': 0.0, 'UnitType': 3, 'Unit': 'mm'}}}, 'Wind': {'Direction': {'Localized': '東北', 'English': 'NE', 'Degrees': 45}, 'Speed': {'Imperial': {'Value': 21.9, 'UnitType': 9, 'Unit': 'mi/h'}, 'Metric': {'Value': 35.2, 'UnitType': 7, 'Unit': 'km/h'}}}, 'Link': 'http://www.accuweather.com/zh/tw/taipei-city/315078/current-weather/315078?lang=zh-tw', 'Past24HourTemperatureDepart ...

# %%
print(curr_weather[0]['ApparentTemperature'])
print(curr_weather[0]['ApparentTemperature']['Metric'])
print(curr_weather[0]['ApparentTemperature']['Metric']['Value'])
print(curr_weather[0]['UVIndex'])
# Out:
# {'Imperial': {'Value': 65.0, 'UnitType': 18, 'Unit': 'F'}, 'Metric': {'Value': 18.3, 'UnitType': 17, 'Unit': 'C'}}
# {'Value': 18.3, 'UnitType': 17, 'Unit': 'C'}
# 18.3
# 0

# %%
print(json.dumps(curr_weather[0]['Visibility'],indent=4))
# Out:
# {
#     "Imperial": {
#         "Value": 6.0,
#         "UnitType": 2,
#         "Unit": "mi"
#     },
#     "Metric": {
#         "Value": 9.7,
#         "UnitType": 6,
#         "Unit": "km"
#     }
# }

# %%
print(json.dumps(curr_weather,indent=4))
# Out:
# [
#     {
#         "RelativeHumidity": 77,
#         "ApparentTemperature": {
#             "Imperial": {
#                 "Value": 65.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 18.3,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "WeatherIcon": 7,
#         "UVIndex": 0,
#         "Pressure": {
#             "Imperial": {
#                 "Value": 30.12,
#                 "UnitType": 12,
#                 "Unit": "inHg"
#             },
#             "Metric": {
#                 "Value": 1020.0,
#                 "UnitType": 14,
#                 "Unit": "mb"
#             }
#         },
#         "UVIndexText": "\u4f4e",
#         "WetBulbTemperature": {
#             "Imperial": {
#                 "Value": 58.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 14.7,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "Ceiling": {
#             "Imperial": {
#                 "Value": 2900.0,
#                 "UnitType": 0,
#                 "Unit": "ft"
#             },
#             "Metric": {
#                 "Value": 884.0,
#                 "UnitType": 5,
#                 "Unit": "m"
#             }
#         },
#         "EpochTime": 1452244800,
#         "RealFeelTemperatureShade": {
#             "Imperial": {
#                 "Value": 57.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 13.7,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "WeatherText": "\u591a\u96f2",
#         "WindChillTemperature": {
#             "Imperial": {
#                 "Value": 63.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 17.2,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "PressureTendency": {
#             "Code": "S",
#             "LocalizedText": "\u7a69\u5b9a"
#         },
#         "DewPoint": {
#             "Imperial": {
#                 "Value": 55.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 12.8,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "CloudCover": 95,
#         "Temperature": {
#             "Imperial": {
#                 "Value": 63.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 17.2,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "MobileLink": "http://m.accuweather.com/zh/tw/taipei-city/315078/current-weather/315078?lang=zh-tw",
#         "TemperatureSummary": {
#             "Past24HourRange": {
#                 "Minimum": {
#                     "Imperial": {
#                         "Value": 61.0,
#                         "UnitType": 18,
#                         "Unit": "F"
#                     },
#                     "Metric": {
#                         "Value": 16.1,
#                         "UnitType": 17,
#                         "Unit": "C"
#                     }
#                 },
#                 "Maximum": {
#                     "Imperial": {
#                         "Value": 64.0,
#                         "UnitType": 18,
#                         "Unit": "F"
#                     },
#                     "Metric": {
#                         "Value": 18.0,
#                         "UnitType": 17,
#                         "Unit": "C"
#                     }
#                 }
#             },
#             "Past6HourRange": {
#                 "Minimum": {
#                     "Imperial": {
#                         "Value": 63.0,
#                         "UnitType": 18,
#                         "Unit": "F"
#                     },
#                     "Metric": {
#                         "Value": 17.2,
#                         "UnitType": 17,
#                         "Unit": "C"
#                     }
#                 },
#                 "Maximum": {
#                     "Imperial": {
#                         "Value": 64.0,
#                         "UnitType": 18,
#                         "Unit": "F"
#                     },
#                     "Metric": {
#                         "Value": 18.0,
#                         "UnitType": 17,
#                         "Unit": "C"
#                     }
#                 }
#             },
#             "Past12HourRange": {
#                 "Minimum": {
#                     "Imperial": {
#                         "Value": 62.0,
#                         "UnitType": 18,
#                         "Unit": "F"
#                     },
#                     "Metric": {
#                         "Value": 16.8,
#                         "UnitType": 17,
#                         "Unit": "C"
#                     }
#                 },
#                 "Maximum": {
#                     "Imperial": {
#                         "Value": 64.0,
#                         "UnitType": 18,
#                         "Unit": "F"
#                     },
#                     "Metric": {
#                         "Value": 18.0,
#                         "UnitType": 17,
#                         "Unit": "C"
#                     }
#                 }
#             }
#         },
#         "Visibility": {
#             "Imperial": {
#                 "Value": 6.0,
#                 "UnitType": 2,
#                 "Unit": "mi"
#             },
#             "Metric": {
#                 "Value": 9.7,
#                 "UnitType": 6,
#                 "Unit": "km"
#             }
#         },
#         "WindGust": {
#             "Speed": {
#                 "Imperial": {
#                     "Value": 21.9,
#                     "UnitType": 9,
#                     "Unit": "mi/h"
#                 },
#                 "Metric": {
#                     "Value": 35.2,
#                     "UnitType": 7,
#                     "Unit": "km/h"
#                 }
#             }
#         },
#         "IsDayTime": false,
#         "LocalObservationDateTime": "2016-01-08T17:20:00+08:00",
#         "ObstructionsToVisibility": "",
#         "PrecipitationSummary": {
#             "Past9Hours": {
#                 "Imperial": {
#                     "Value": 0.0,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 0.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "Past12Hours": {
#                 "Imperial": {
#                     "Value": 0.03,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 1.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "Precipitation": {
#                 "Imperial": {
#                     "Value": 0.0,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 0.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "Past3Hours": {
#                 "Imperial": {
#                     "Value": 0.0,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 0.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "Past18Hours": {
#                 "Imperial": {
#                     "Value": 0.11,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 3.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "PastHour": {
#                 "Imperial": {
#                     "Value": 0.0,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 0.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "Past24Hours": {
#                 "Imperial": {
#                     "Value": 0.11,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 3.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             },
#             "Past6Hours": {
#                 "Imperial": {
#                     "Value": 0.0,
#                     "UnitType": 1,
#                     "Unit": "in"
#                 },
#                 "Metric": {
#                     "Value": 0.0,
#                     "UnitType": 3,
#                     "Unit": "mm"
#                 }
#             }
#         },
#         "Wind": {
#             "Direction": {
#                 "Localized": "\u6771\u5317",
#                 "English": "NE",
#                 "Degrees": 45
#             },
#             "Speed": {
#                 "Imperial": {
#                     "Value": 21.9,
#                     "UnitType": 9,
#                     "Unit": "mi/h"
#                 },
#                 "Metric": {
#                     "Value": 35.2,
#                     "UnitType": 7,
#                     "Unit": "km/h"
#                 }
#             }
#         },
#         "Link": "http://www.accuweather.com/zh/tw/taipei-city/315078/current-weather/315078?lang=zh-tw",
#         "Past24HourTemperatureDeparture": {
#             "Imperial": {
#                 "Value": 0.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 0.0,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         },
#         "Precip1hr": {
#             "Imperial": {
#                 "Value": 0.0,
#                 "UnitType": 1,
#                 "Unit": "in"
#             },
#             "Metric": {
#                 "Value": 0.0,
#                 "UnitType": 3,
#                 "Unit": "mm"
#             }
#         },
#         "RealFeelTemperature": {
#             "Imperial": {
#                 "Value": 57.0,
#                 "UnitType": 18,
#                 "Unit": "F"
#             },
#             "Metric": {
#                 "Value": 13.7,
#                 "UnitType": 17,
#                 "Unit": "C"
#             }
#         }
#     }
# ]
